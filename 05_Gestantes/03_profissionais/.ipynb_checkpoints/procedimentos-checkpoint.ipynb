# %%
import pyodbc
import pandas as pd

# %%
host = '200.137.215.27'
port = 31010
uid = 'daniel'
pwd = 'p7USWgsqaEH3CWe'
driver = 'Dremio Connector'

cnxn = pyodbc.connect("Driver={};ConnectionType=Direct;HOST={};PORT={};AuthenticationType=Plain;UID={};PWD={}".format(driver, host,port,uid,pwd),autocommit=True)

sql = '''SELECT * FROM Dados.sia.pa LIMIT 100'''

df = pd.read_sql(sql,cnxn)
df.head()
# Out:
# C:\Users\Lapei_Cigets\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#   PA_CODUNI PA_GESTAO PA_CONDIC PA_UFMUN PA_REGCT PA_INCOUT PA_INCURG  \
# 0   2001586    120000        EP   120040     0000      0000      0000
# 1   2001586    120000        EP   120040     0000      0000      0000
# 2   2001586    120000        EP   120040     0000      0000      0000
# 3   3542734    120000        EP   120040     0000      0000      0000
# 4   3542734    120000        EP   120040     0000      0000      0000
#
#   PA_TPUPS PA_TIPPRE PA_MN_IND  ... PA_ETNIA  uf competencia  \
# 0       05        40         I  ...     None  AC       08-07
# 1       05        40         I  ...     None  AC       08-07
# 2       05        40         I  ...     None  AC       08-07
# 3       43        40         M  ...     None  AC       08-07
# 4       43        40         M  ...     None  AC       08-07
#
#             arquivo PA_VL_CF PA_VL_CL PA_VL_INC PA_SRV_C PA_INE PA_NAT_JUR
# 0  PAAC0807.parquet     None     None      None     None   None       None
# 1  PAAC0807.parquet     None     None      None     None   None       None
# 2  PAAC0807.parquet     None     None      None     None   None       None
# 3  PAAC0807.parquet     None     None      None     None   None       None
# 4  PAAC0807.parquet     None     None      None     None   None       None
#
# [5 rows x 63 columns]
