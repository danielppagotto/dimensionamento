# %%
import pyodbc
import pandas as pd
import requests
from datetime import datetime

# %% [markdown]
# # Calculando Demanda

# %% [markdown]
# Vamos pegar um conjunto de dados de previsão para as regiões de saúde de Goiás

# %%
df = pd.read_excel("previsoes_go.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Estado    649 non-null    object
#  1   codibge   649 non-null    int64
#  2   mae_mlp   649 non-null    float64
#  3   mape_mlp  649 non-null    float64
#  4   mes_ano   649 non-null    object
#  5   qtd       649 non-null    float64
#  6   data      649 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 35.6+ KB

# %%
df = df.drop(columns=['Estado','mae_mlp','mape_mlp','mes_ano'])
df.head()
# Out:
#    codibge          qtd       data
# 0    52001  2228.074325 2022-12-01
# 1    52002  1105.240907 2023-01-01
# 2    52011   637.147580 2023-01-01
# 3    52004  1044.177786 2023-01-01
# 4    52013   176.677516 2023-01-01

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   codibge  649 non-null    int64
#  1   qtd      649 non-null    float64
#  2   data     649 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 15.3 KB

# %%
df['qtd'] = df['qtd'].round()
df['qtd'] = df['qtd'].astype(int)

df['ano_mes']=df['data'].astype(str)
df['ano_mes'] = df['ano_mes'].str.slice(start = 0, stop = 7)

df.head()
# Out:
#    codibge   qtd       data  ano_mes
# 0    52001  2228 2022-12-01  2022-12
# 1    52002  1105 2023-01-01  2023-01
# 2    52011   637 2023-01-01  2023-01
# 3    52004  1044 2023-01-01  2023-01
# 4    52013   177 2023-01-01  2023-01

# %% [markdown]
# Vamos utilizar apenas a **população SUS dependente**. Portanto, vamos deduzir um percentual da população detentora de plano de saúde.

# %%
plano = pd.read_csv("beneficiarios_plano_saude.csv")

plano = plano.loc[(plano.mes == 6)]

plano = plano[['cod_regsaud','percentual_pop_coberta']]

df = df.merge(plano, left_on='codibge', right_on='cod_regsaud', how = 'left')

df['qtd_sus'] = df['qtd'] * ((100 - df['percentual_pop_coberta'])/100)
df['qtd_sus'] = df['qtd_sus'].round()
df['qtd_sus'] = df['qtd_sus'].astype(int)


df.head()
# Out:
#    codibge   qtd       data  ano_mes  cod_regsaud  percentual_pop_coberta  \
# 0    52001  2228 2022-12-01  2022-12        52001                   48.75
# 1    52002  1105 2023-01-01  2023-01        52002                   24.64
# 2    52011   637 2023-01-01  2023-01        52011                   27.56
# 3    52004  1044 2023-01-01  2023-01        52004                   13.86
# 4    52013   177 2023-01-01  2023-01        52013                   14.49
#
#    qtd_sus
# 0     1142
# 1      833
# 2      461
# 3      899
# 4      151

# %% [markdown]
# Vamos usar o API para verificar os procedimentos necessários para cada nascido vivo de um mês de referência e região de saúde

# %%
dfs = [] 

for _, row in df.iterrows():
    qtd_nascidos = round(row['qtd_sus'])
    ano_mes = row['ano_mes']
    url = f'http://200.137.215.27:5025/calcula_procedimentos?mes_ano={ano_mes}&nascidos_vivos={qtd_nascidos}'
    print("Chamando", url)
    resultado = requests.get(url)
    df_it = pd.DataFrame(resultado.json())
    df_it['ano_mes'] = row['ano_mes'] 
    df_it['qtd_nascidos'] = qtd_nascidos
    df_it['regiao'] = row['codibge']
    dfs.append(df_it)
    df_full = pd.concat(dfs, ignore_index=True)
# Out:
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2022-12&nascidos_vivos=1142
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=833
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=461
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=899
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=151
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=170
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=101
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=339
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=186
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=144
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=297
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=226
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=57
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=122
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=143
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=114
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=101
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=214
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-01&nascidos_vivos=1198
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=834
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=432
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=877
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=142
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=169
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=116
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=344
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=179
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=149
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=293
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=236
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=65
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=109
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=138
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=109
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=101
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=200
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-02&nascidos_vivos=1112
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=922
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=495
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=963
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=162
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=179
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=126
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=351
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=207
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=155
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=297
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=244
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=68
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=127
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=147
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=113
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=102
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=201
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-03&nascidos_vivos=1263
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=926
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=517
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=983
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=150
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=176
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=124
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=347
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=206
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=155
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=292
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=257
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=65
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=123
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=155
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=117
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=105
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=221
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-04&nascidos_vivos=1210
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=889
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=509
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=978
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=159
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=173
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=124
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=343
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=212
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=157
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=290
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=258
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=62
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=127
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=161
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=108
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=118
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=222
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-05&nascidos_vivos=1245
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=870
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=473
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=984
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=159
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=167
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=115
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=341
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=186
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=160
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=290
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=233
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=62
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=127
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=156
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=109
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=109
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=230
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-06&nascidos_vivos=1184
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=846
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=475
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=910
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=151
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=156
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=108
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=340
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=182
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=160
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=287
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=224
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=66
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=120
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=153
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=110
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=108
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=232
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-07&nascidos_vivos=1133
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=865
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=490
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=921
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=152
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=156
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=98
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=329
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=184
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=158
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=282
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=233
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=69
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=125
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=154
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=114
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=104
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=236
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-08&nascidos_vivos=1115
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=853
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=477
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=917
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=156
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=152
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=109
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=329
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=186
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=154
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=289
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=234
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=66
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=118
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=152
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=116
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=110
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=230
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-09&nascidos_vivos=1166
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=829
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=485
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=923
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=150
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=151
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=110
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=327
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=174
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=148
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=283
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=221
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=64
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=117
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=151
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=118
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=106
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=220
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-10&nascidos_vivos=1144
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=781
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=459
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=867
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=152
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=155
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=103
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=329
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=178
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=149
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=287
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=223
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=62
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=125
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=143
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=118
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=102
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=222
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-11&nascidos_vivos=1089
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=803
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=501
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=848
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=152
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=159
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=110
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=328
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=179
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=142
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=290
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=227
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=62
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=121
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=143
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=116
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=100
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=236
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2023-12&nascidos_vivos=1118
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=851
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=456
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=890
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=152
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=168
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=106
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=334
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=181
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=144
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=290
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=229
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=65
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=125
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=144
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=122
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=100
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=224
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-01&nascidos_vivos=1184
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=848
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=426
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=892
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=145
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=167
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=115
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=336
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=183
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=141
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=290
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=256
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=66
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=118
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=142
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=121
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=98
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=213
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-02&nascidos_vivos=1078
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=927
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=498
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=951
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=153
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=176
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=125
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=342
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=203
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=147
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=285
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=257
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=62
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=130
# Chamando http://200.137.215.27:5025/calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=148
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# TimeoutError: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     397             else:
# --> 398                 conn.request(method, url, **httplib_request_kw)
#     399
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in request(self, method, url, body, headers)
#     238             headers["User-Agent"] = _get_default_user_agent()
# --> 239         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     240
#
# ~\anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1284         """Send a complete request to the server."""
# -> 1285         self._send_request(method, url, body, headers, encode_chunked)
#    1286
#
# ~\anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1330             body = _encode(body, 'body')
# -> 1331         self.endheaders(body, encode_chunked=encode_chunked)
#    1332
#
# ~\anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1279             raise CannotSendHeader()
# -> 1280         self._send_output(message_body, encode_chunked=encode_chunked)
#    1281
#
# ~\anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1039         del self._buffer[:]
# -> 1040         self.send(msg)
#    1041
#
# ~\anaconda3\lib\http\client.py in send(self, data)
#     979             if self.auto_open:
# --> 980                 self.connect()
#     981             else:
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     204     def connect(self):
# --> 205         conn = self._new_conn()
#     206         self._prepare_conn(conn)
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x0000025338E770A0>: Failed to establish a new connection: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu
# corretamente após um período de tempo ou a conexão estabelecida falhou
# porque o host conectado não respondeu
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPConnectionPool(host='200.137.215.27', port=5025): Max retries exceeded with url: /calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=148 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000025338E770A0>: Failed to establish a new connection: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu\r\ncorretamente após um período de tempo ou a conexão estabelecida falhou\r\nporque o host conectado não respondeu'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_137084\856699423.py in <module>
#       6     url = f'http://200.137.215.27:5025/calcula_procedimentos?mes_ano={ano_mes}&nascidos_vivos={qtd_nascidos}'
#       7     print("Chamando", url)
# ----> 8     resultado = requests.get(url)
#       9     df_it = pd.DataFrame(resultado.json())
#      10     df_it['ano_mes'] = row['ano_mes']
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     563                 raise SSLError(e, request=request)
#     564
# --> 565             raise ConnectionError(e, request=request)
#     566
#     567         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='200.137.215.27', port=5025): Max retries exceeded with url: /calcula_procedimentos?mes_ano=2024-03&nascidos_vivos=148 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000025338E770A0>: Failed to establish a new connection: [WinError 10060] Uma tentativa de conexão falhou porque o componente conectado não respondeu\r\ncorretamente após um período de tempo ou a conexão estabelecida falhou\r\nporque o host conectado não respondeu'))

# %%
df_full.head()
#df_full.to_csv("arquivos PBI/total_procedimentos_PBI.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_164592\207941691.py in <module>
# ----> 1 df_full.info()
#       2 #df_full.to_csv("arquivos PBI/total_procedimentos_PBI.csv")
#
# NameError: name 'df_full' is not defined

# %% [markdown]
# **Descrição de variáveis**
# - codigo_sigtap: código de identificação única de um procedimento (um procedimento pode ocorrer múltiplas vezes ao longo da gestação, como o pré-natal)
# - mes: mês de referência que aquele procedimento deve ser realizado (mês 1 = primeiro mês de gestação)
# - parametro: quantos procedimentos naquele mês para o total de gestantes devem ser realizados (ex.: existem procedimentos que só metade das gestantes precisam fazer)
# - procedimento: nome do procedimento
# - tipo_procedimento: tipo de procedimento
# - Público: Pode ser gestantes (risco habiual ou alto risco) ou nascidos. Via de regra pode ser todas ou, para alguns procedimentos, as de alto risco
# - nivel_atencao: nível de atenção onde aquele procedimento geralmente é realizado
# - quantidade: quantidade de procedimentos que devem ser realizados tendo em vista as colunas parametro e qtd_nascidos
# - mês_procedimento_realizado: mês da gestação que aquele procedimento deve ser realizado, tomando como referência as colunas ano_mes e mes
# - qtd_nascidos: quantidade de registros de nascidos vivos para a região de saúde, já descontado o S
# - regiao: código IBGE que identifica a região de saúde

# %% [markdown]
# # Calculando procedimentos por mês

# %% [markdown]
# Agora vamos calcular a quantidade de procedimentos por mês de realização do procedimento

# %%
procedimentos_mes = df_full.groupby(['regiao','ano_mes','mês_procedimento_realizado','nivel_atencao',
                                     'tipo_procedimento','codigo_sigtap','qtd_nascidos'])['quantidade'].sum().reset_index()

# %%
procedimentos_mes[["mês_procedimento_realizado"]] = procedimentos_mes[["mês_procedimento_realizado"]].apply(pd.to_datetime) 
procedimentos_mes['codigo_sigtap'] = procedimentos_mes['codigo_sigtap'].astype('str') 

procedimentos_mes.head()
# Out:
#    regiao  ano_mes mês_procedimento_realizado nivel_atencao  \
# 0   52001  2022-12                 2022-04-01           APS
# 1   52001  2022-12                 2022-05-01           APS
# 2   52001  2022-12                 2022-05-01           APS
# 3   52001  2022-12                 2022-05-01           APS
# 4   52001  2022-12                 2022-05-01           APS
#
#       tipo_procedimento codigo_sigtap  qtd_nascidos  quantidade
# 0  Consultas ou Visitas     301010110          1142      1142.0
# 1  Consultas ou Visitas     301010110          1142      1142.0
# 2  Consultas ou Visitas     301010137          1142      1142.0
# 3                Exames     202020355          1142      1142.0
# 4                Exames     202020380          1142      1142.0

# %% [markdown]
# Considerando o total de procedimentos, vamos computar em horas primeiro. Para isso, vamos ler uma planilha com estimativas de tempos dos procedimento. **Em uma implementação de sistema, é requisito que os tempos sejam ajustados pelo usuário.**

# %%
tempos = pd.read_excel("calendario-procedimentos.xlsx", sheet_name="procedimentos_tempo") 
tempos['codigo_sigtap'] = tempos['codigo_sigtap'].astype('str')
tempos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   codigo_sigtap  61 non-null     object
#  1   procedimento   61 non-null     object
#  2   Tempo          61 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
df_tempos = procedimentos_mes.merge(tempos, on = 'codigo_sigtap', how = 'left')

df_tempos['horasProfissionais'] = df_tempos['quantidade'] * df_tempos['Tempo'] 

df_tempos.head()
# Out:
#    regiao  ano_mes mês_procedimento_realizado nivel_atencao  \
# 0   52001  2022-12                 2022-04-01           APS
# 1   52001  2022-12                 2022-05-01           APS
# 2   52001  2022-12                 2022-05-01           APS
# 3   52001  2022-12                 2022-05-01           APS
# 4   52001  2022-12                 2022-05-01           APS
#
#       tipo_procedimento codigo_sigtap  qtd_nascidos  quantidade  \
# 0  Consultas ou Visitas     301010110          1142      1142.0
# 1  Consultas ou Visitas     301010110          1142      1142.0
# 2  Consultas ou Visitas     301010137          1142      1142.0
# 3                Exames     202020355          1142      1142.0
# 4                Exames     202020380          1142      1142.0
#
#                   procedimento     Tempo  horasProfissionais
# 0           Consulta pré-natal  0.500000          571.000000
# 1           Consulta pré-natal  0.500000          571.000000
# 2            Visita domiciliar  0.500000          571.000000
# 3  Eletroforese de Hemoglobina  0.166667          190.333333
# 4                    Hemograma  0.083333           95.166667

# %% [markdown]
# Agora vamos ver os perfis de profissionais que atuam nos procedimentos. Temos profissionais que podem atuar em mais de um procedimento (ex.: médicos e enfermeiros podem atuar no pré-natal). Por isso que tem essa contagem resultando no df mix. Se o procedimento é realizado por dois profissionais, dividimos as horasProfissionais para duas categorias.

# %%
df_profissionais = pd.read_excel("calendario-procedimentos.xlsx", sheet_name="procedimentos_profissionais")

df_profissionais['codigo_sigtap'] = df_profissionais['codigo_sigtap'].astype('str')

mix = df_profissionais.groupby(['codigo_sigtap'])['CBO'].count().reset_index()

mix = mix.rename(columns={"CBO":"qtd"})

# %%
df_tempos = df_tempos.merge(mix, on = 'codigo_sigtap', how = 'left') 

df_tempos['horas_categoria'] = df_tempos['horasProfissionais'] / df_tempos['qtd']

df_tempos.head()
# Out:
#    regiao  ano_mes mês_procedimento_realizado nivel_atencao  \
# 0   52001  2022-12                 2022-04-01           APS
# 1   52001  2022-12                 2022-05-01           APS
# 2   52001  2022-12                 2022-05-01           APS
# 3   52001  2022-12                 2022-05-01           APS
# 4   52001  2022-12                 2022-05-01           APS
#
#       tipo_procedimento codigo_sigtap  qtd_nascidos  quantidade  \
# 0  Consultas ou Visitas     301010110          1142      1142.0
# 1  Consultas ou Visitas     301010110          1142      1142.0
# 2  Consultas ou Visitas     301010137          1142      1142.0
# 3                Exames     202020355          1142      1142.0
# 4                Exames     202020380          1142      1142.0
#
#                   procedimento     Tempo  horasProfissionais  qtd  \
# 0           Consulta pré-natal  0.500000          571.000000    2
# 1           Consulta pré-natal  0.500000          571.000000    2
# 2            Visita domiciliar  0.500000          571.000000    1
# 3  Eletroforese de Hemoglobina  0.166667          190.333333    1
# 4                    Hemograma  0.083333           95.166667    1
#
#    horas_categoria
# 0       285.500000
# 1       285.500000
# 2       571.000000
# 3       190.333333
# 4        95.166667

# %% [markdown]
# Aqui dividimos o quantitativo de profissionais por 126, que é o correspondente de horas líquidas mensais de um profissional de 40h semanais para calcular a métrica da FTE40

# %%
df_tempo_prof = df_tempos.merge(df_profissionais, on = 'codigo_sigtap', how = 'left')

df_tempo_prof = df_tempo_prof.groupby(['regiao', 'mês_procedimento_realizado','nivel_atencao', 'qtd_nascidos', 
                                       'ano_mes','CBO'])['horas_categoria'].sum().reset_index()

df_tempo_prof['fte40'] = df_tempo_prof['horas_categoria']/126

df_tempo_prof.head()
# Out:
#    regiao mês_procedimento_realizado nivel_atencao  qtd_nascidos  ano_mes  \
# 0   52001                 2022-04-01           APS          1142  2022-12
# 1   52001                 2022-04-01           APS          1142  2022-12
# 2   52001                 2022-05-01           APS          1142  2022-12
# 3   52001                 2022-05-01           APS          1142  2022-12
# 4   52001                 2022-05-01           APS          1142  2022-12
#
#       CBO  horas_categoria      fte40
# 0  223505            285.5   2.265873
# 1  225130            285.5   2.265873
# 2  221205           2226.9  17.673810
# 3  223505            513.9   4.078571
# 4  225130            513.9   4.078571

# %%
#df_tempo_prof.to_csv("df_prof_go.csv")
